# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


df = pd.read_csv('./combined_data.csv')
log_data = df['Description']

# Tokenize the log data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(log_data)
total_words = len(tokenizer.word_index) + 1

# Create input sequences and labels
input_sequences = []
for line in log_data:
    # Split the log entry based on the '\r\n' delimiter
    tokens = line.split('\r\n')
    
    # Tokenize the split tokens and create n-grams
    for token in tokens:
        token_list = tokenizer.texts_to_sequences([token])[0]
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            input_sequences.append(n_gram_sequence)

max_sequence_length = max([len(x) for x in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

X, y = input_sequences[:,:-1],input_sequences[:,-1]
y = np.array(tf.keras.utils.to_categorical(y, num_classes=total_words))

# Build the model
model = Sequential()
model.add(Embedding(total_words, 50, input_length=max_sequence_length-1))
model.add(LSTM(100))
model.add(Dense(total_words, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X, y, epochs=1, verbose=1)

# Generate artificial logs
def generate_fake_log(seed_text, next_words, model, max_sequence_length):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

# Generate 5 fake logs
for _ in range(20):
    seed_text = random.choice(log_data)
    fake_log = generate_fake_log(seed_text, next_words=10, model=model, max_sequence_length=max_sequence_length)
    print(fake_log)
    print("\n" + "="*50 + "\n")
# Out:
# 1995/1995 [==============================] - 65s 32ms/step - loss: 3.2203 - accuracy: 0.3800
# 1/1 [==============================] - 0s 268ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:04:34.978
# ProcessGuid: {1c492278-fb72-656c-5d02-000000000500}
# ProcessId: 6484
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:04:58.364
# ProcessGuid: {1c492278-fb87-656c-6202-000000000500}
# ProcessId: 5676
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:08:43.817
# ProcessGuid: {1c492278-fc68-656c-b402-000000000500}
# ProcessId: 3780
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:18:20.215
# ProcessGuid: {1c492278-feac-656c-fe02-000000000500}
# ProcessId: 4608
# Image: C:\Users\user1\AppData\Local\Microsoft\OneDrive\21.220.1024.0005\FileCoAuth.exe
# FileVersion: 21.220.1024.0005
# Description: Microsoft OneDriveFile Co-Authoring Executable
# Product: Microsoft OneDrive
# Company: Microsoft Corporation
# OriginalFileName: FileCoAuth.exe
# CommandLine: "C:\Users\user1\AppData\Local\Microsoft\OneDrive\21.220.1024.0005\FileCoAuth.exe" -Embedding
# CurrentDirectory: C:\Windows\system32\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Medium
# Hashes: SHA256=EE51F6C4623C642F58C40794937C6C5A61C2FD6E8382EABA4DE0ACAA40A7BD7D
# ParentProcessGuid: {1c492278-ecba-656c-0d00-000000000500}
# ParentProcessId: 812
# ParentImage: C:\Windows\System32\svchost.exe
# ParentCommandLine: C:\Windows\system32\svchost.exe -k DcomLaunch -p
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:14:24.816
# ProcessGuid: {1c492278-fdc0-656c-d902-000000000500}
# ProcessId: 1460
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# FileVersion: 119.0.6045.200
# Description: Google Chrome
# Product: Google Chrome
# Company: Google LLC
# OriginalFileName: chrome.exe
# CommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe" --type=utility --utility-sub-type=quarantine.mojom.Quarantine --lang=en-US --service-sandbox-type=none --mojo-platform-channel-handle=12036 --field-trial-handle=1916,i,17040888337244139981,11734970527589297732,262144 /prefetch:8
# CurrentDirectory: C:\Program Files\Google\Chrome\Application\119.0.6045.200\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Medium
# Hashes: SHA256=33F662AEC0E59C12809D5F4CF04E6626AC08728CDC2835EAD0650910BDF0F772
# ParentProcessGuid: {1c492278-ece7-656c-8600-000000000500}
# ParentProcessId: 7420
# ParentImage: C:\Program Files\Google\Chrome\Application\chrome.exe
# ParentCommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe"
# ParentUser: WINDOWS-10-VM\user1 1916 i microsoft 1701637300081273 launch time ticks at field trial
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 21:51:19.670
# ProcessGuid: {1c492278-f853-656c-7301-000000000500}
# ProcessId: 7172
# Image: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\mscorsvw.exe
# User: NT AUTHORITY\SYSTEM microsoft net framework v4 0 30319 ngen 11734970527589297732 user1 1916
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:13:12.658
# ProcessGuid: {1c492278-fd78-656c-c602-000000000500}
# ProcessId: 3156
# Image: C:\Windows\System32\SearchProtocolHost.exe
# FileVersion: 7.0.19041.2673 (WinBuild.160101.0800)
# Description: Microsoft Windows Search Protocol Host
# Product: Windows® Search
# Company: Microsoft Corporation
# OriginalFileName: SearchProtocolHost.exe
# CommandLine: "C:\Windows\system32\SearchProtocolHost.exe" Global\UsGthrFltPipeMssGthrPipe7_ Global\UsGthrCtrlFltPipeMssGthrPipe7 1 -2147483646 "Software\Microsoft\Windows Search" "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT; MS Search 4.0 Robot)" "C:\ProgramData\Microsoft\Search\Data\Temp\usgthrsvc" "DownLevelDaemon"
# CurrentDirectory: C:\Windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {1c492278-ecba-656c-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA256=3FAC16B7DF4E73B623DB993A23957A05A8857C1C1F0217C80E385037F4EDF0D0
# ParentProcessGuid: {1c492278-ecbf-656c-6900-000000000500}
# ParentProcessId: 5332
# ParentImage: C:\Windows\System32\SearchIndexer.exe
# ParentCommandLine: C:\Windows\system32\SearchIndexer.exe /Embedding
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:15:28.106
# ProcessGuid: {1c492278-fe00-656c-e102-000000000500}
# ProcessId: 4860
# Image: C:\Windows\System32\wbem\WmiPrvSE.exe
# FileVersion: 10.0.19041.546 (WinBuild.160101.0800)
# Description: WMI Provider Host
# Product: Microsoft® Windows® Operating System
# Company: Microsoft Corporation
# OriginalFileName: Wmiprvse.exe
# CommandLine: C:\Windows\system32\wbem\wmiprvse.exe -secured -Embedding
# CurrentDirectory: C:\Windows\system32\
# User: NT AUTHORITY\NETWORK SERVICE
# LogonGuid: {1c492278-ecba-656c-e403-000000000000}
# LogonId: 0x3E4
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA256=2198A7B58BCCB758036B969DDAE6CC2ECE07565E2659A7C541A313A0492231A3
# ParentProcessGuid: {1c492278-ecba-656c-0d00-000000000500}
# ParentProcessId: 812
# ParentImage: C:\Windows\System32\svchost.exe
# ParentCommandLine: C:\Windows\system32\svchost.exe -k DcomLaunch -p
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:04:34.987
# ProcessGuid: {1c492278-fb72-656c-5e02-000000000500}
# ProcessId: 4712
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:08:46.852
# ProcessGuid: {1c492278-fc6e-656c-c302-000000000500}
# ProcessId: 8464
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# FileVersion: 119.0.6045.200
# Description: Google Chrome
# Product: Google Chrome
# Company: Google LLC
# OriginalFileName: chrome.exe
# CommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe" --type=renderer --enable-chrome-cart --disable-nacl --disable-gpu-compositing --lang=en-US --device-scale-factor=1 --num-raster-threads=2 --enable-main-frame-before-activation --renderer-client-id=133 --time-ticks-at-unix-epoch=-1701637300081273 --launch-time-ticks=4026899545 --mojo-platform-channel-handle=10960 --field-trial-handle=1916,i,17040888337244139981,11734970527589297732,262144 /prefetch:1
# CurrentDirectory: C:\Program Files\Google\Chrome\Application\119.0.6045.200\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Low
# Hashes: SHA256=33F662AEC0E59C12809D5F4CF04E6626AC08728CDC2835EAD0650910BDF0F772
# ParentProcessGuid: {1c492278-ece7-656c-8600-000000000500}
# ParentProcessId: 7420
# ParentImage: C:\Program Files\Google\Chrome\Application\chrome.exe
# ParentCommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe"
# ParentUser: WINDOWS-10-VM\user1 1916 i microsoft 1701637300081273 launch time ticks at field trial
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 21:52:38.445
# ProcessGuid: {1c492278-f8a6-656c-fd01-000000000500}
# ProcessId: 4648
# Image: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngen.exe
# User: NT AUTHORITY\SYSTEM microsoft net framework v4 0 30319 ngen 11734970527589297732 user1 1916
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 21:52:39.019
# ProcessGuid: {1c492278-f8a7-656c-1f02-000000000500}
# ProcessId: 1852
# Image: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngen.exe
# FileVersion: 4.8.4320.0 built by: NET48REL1LAST_C
# Description: Microsoft Common Language Runtime native compiler
# Product: Microsoft® .NET Framework
# Company: Microsoft Corporation
# OriginalFileName: ngen.exe
# CommandLine: "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngen.exe" uninstall "C:\Windows\assembly\NativeImages_v4.0.30319_64\Microsoft.W69ef49d2#\281d38ef19f7c83b04c409ff60d72377\Microsoft.Windows.Diagnosis.Commands.GetDiagInput.ni.dll" /noroot /LegacyServiceBehavior
# CurrentDirectory: C:\Windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {1c492278-ecba-656c-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA256=A446D35F5E60BDAE1A7117B71D90ABB0FEA424EE416B0E0ECD2C485DC5939A68
# ParentProcessGuid: {1c492278-f851-656c-6301-000000000500}
# ParentProcessId: 5360
# ParentImage: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngentask.exe
# ParentCommandLine: "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\NGenTask.exe" /RuntimeWide /Critical /StopEvent:512
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:04:01.198
# ProcessGuid: {1c492278-fb51-656c-5402-000000000500}
# ProcessId: 7004
# Image: C:\Windows\System32\backgroundTaskHost.exe
# FileVersion: 10.0.19041.546 (WinBuild.160101.0800)
# Description: Background Task Host
# Product: Microsoft® Windows® Operating System
# Company: Microsoft Corporation
# OriginalFileName: backgroundTaskHost.exe
# CommandLine: "C:\Windows\system32\BackgroundTaskHost.exe" -ServerName:BackgroundTaskHost.WebAccountProvider
# CurrentDirectory: C:\Windows\SystemApps\Microsoft.AAD.BrokerPlugin_cw5n1h2txyewy\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: AppContainer
# Hashes: SHA256=20330D3CA71D58F4AEB432676CB6A3D5B97005954E45132FB083E90782EFDD50
# ParentProcessGuid: {1c492278-ecba-656c-0d00-000000000500}
# ParentProcessId: 812
# ParentImage: C:\Windows\System32\svchost.exe
# ParentCommandLine: C:\Windows\system32\svchost.exe -k DcomLaunch -p
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:08:36.690
# ProcessGuid: {1c492278-fc64-656c-9a02-000000000500}
# ProcessId: 972
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# FileVersion: 119.0.6045.200
# Description: Google Chrome
# Product: Google Chrome
# Company: Google LLC
# OriginalFileName: chrome.exe
# CommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe" --type=renderer --enable-chrome-cart --disable-nacl --disable-gpu-compositing --lang=en-US --device-scale-factor=1 --num-raster-threads=2 --enable-main-frame-before-activation --renderer-client-id=92 --time-ticks-at-unix-epoch=-1701637300081273 --launch-time-ticks=4016735525 --mojo-platform-channel-handle=7532 --field-trial-handle=1916,i,17040888337244139981,11734970527589297732,262144 /prefetch:1
# CurrentDirectory: C:\Program Files\Google\Chrome\Application\119.0.6045.200\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Low
# Hashes: SHA256=33F662AEC0E59C12809D5F4CF04E6626AC08728CDC2835EAD0650910BDF0F772
# ParentProcessGuid: {1c492278-ece7-656c-8600-000000000500}
# ParentProcessId: 7420
# ParentImage: C:\Program Files\Google\Chrome\Application\chrome.exe
# ParentCommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe"
# ParentUser: WINDOWS-10-VM\user1 1916 i microsoft 1701637300081273 launch time ticks at field trial
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 21:52:11.611
# ProcessGuid: {1c492278-f88b-656c-b301-000000000500}
# ProcessId: 300
# Image: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\mscorsvw.exe
# User: NT AUTHORITY\SYSTEM microsoft net framework v4 0 30319 ngen 11734970527589297732 user1 1916
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:01:50.461
# ProcessGuid: {1c492278-face-656c-3902-000000000500}
# ProcessId: 5196
# Image: C:\Windows\System32\dllhost.exe
# FileVersion: 10.0.19041.546 (WinBuild.160101.0800)
# Description: COM Surrogate
# Product: Microsoft® Windows® Operating System
# Company: Microsoft Corporation
# OriginalFileName: dllhost.exe
# CommandLine: C:\Windows\system32\DllHost.exe /Processid:{AB8902B4-09CA-4BB6-B78D-A8F59079A8D5}
# CurrentDirectory: C:\Windows\system32\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Medium
# Hashes: SHA256=E7FC40B41AA8B83841A0B96D169EAF0800AA784733E636935374D56536253F10
# ParentProcessGuid: {1c492278-ecba-656c-0d00-000000000500}
# ParentProcessId: 812
# ParentImage: C:\Windows\System32\svchost.exe
# ParentCommandLine: C:\Windows\system32\svchost.exe -k DcomLaunch -p
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:08:43.525
# ProcessGuid: {1c492278-fc65-656c-a402-000000000500}
# ProcessId: 1832
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 21:52:12.399
# ProcessGuid: {1c492278-f88c-656c-c201-000000000500}
# ProcessId: 7916
# Image: C:\Windows\Microsoft.NET\Framework\v4.0.30319\mscorsvw.exe
# FileVersion: 4.8.4320.0 built by: NET48REL1LAST_C
# Description: .NET Runtime Optimization Service
# Product: Microsoft® .NET Framework
# Company: Microsoft Corporation
# OriginalFileName: mscorsvw.exe
# CommandLine: C:\Windows\Microsoft.NET\Framework\v4.0.30319\mscorsvw.exe -StartupEvent 210 -InterruptEvent 0 -NGENProcess 188 -Pipe 208 -Comment "NGen Worker Process"
# CurrentDirectory: C:\Windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {1c492278-ecba-656c-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA256=3E5099F573601926E59862FBA2495974688E72677C73F10E4C99E26A76CDCF37
# ParentProcessGuid: {1c492278-f851-656c-6801-000000000500}
# ParentProcessId: 6000
# ParentImage: C:\Windows\Microsoft.NET\Framework\v4.0.30319\ngen.exe
# ParentCommandLine: "C:\Windows\Microsoft.NET\Framework\v4.0.30319\ngen.exe" ExecuteQueuedItems 2 /LegacyServiceBehavior
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:08:43.821
# ProcessGuid: {1c492278-fc68-656c-b602-000000000500}
# ProcessId: 4088
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 21:51:40.810
# ProcessGuid: {1c492278-f86c-656c-8001-000000000500}
# ProcessId: 3676
# Image: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\mscorsvw.exe
# FileVersion: 4.8.4320.0 built by: NET48REL1LAST_C
# Description: .NET Runtime Optimization Service
# Product: Microsoft® .NET Framework
# Company: Microsoft Corporation
# OriginalFileName: mscorsvw.exe
# CommandLine: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\mscorsvw.exe -StartupEvent 278 -InterruptEvent 0 -NGENProcess 2e4 -Pipe 2d4 -Comment "NGen Worker Process"
# CurrentDirectory: C:\Windows\system32\
# User: NT AUTHORITY\SYSTEM
# LogonGuid: {1c492278-ecba-656c-e703-000000000000}
# LogonId: 0x3E7
# TerminalSessionId: 0
# IntegrityLevel: System
# Hashes: SHA256=DA1087BA2641EFD77D85E5838AEB6C333E80CAA9F24C889FD2DE2E0B58F8D1A5
# ParentProcessGuid: {1c492278-f851-656c-6701-000000000500}
# ParentProcessId: 5404
# ParentImage: C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngen.exe
# ParentCommandLine: "C:\Windows\Microsoft.NET\Framework64\v4.0.30319\ngen.exe" ExecuteQueuedItems 2 /LegacyServiceBehavior
# ParentUser: NT AUTHORITY\SYSTEM microsoft handle at field trial 11734970527589297732 262144 prefetch 1 1916

# %%
# Saving models trained weights
model.save_weights('model_weights.h5')

# %%
# Used to load existing models weights
model.load_weights('model_weights.h5')

# Generate artificial logs
def generate_fake_log(seed_text, next_words, model, max_sequence_length):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                print(output_word)
                break
        seed_text += " " + output_word
    return seed_text

# Generate 5 fake logs
for _ in range(3):
    seed_text = random.choice(log_data)
    fake_log = generate_fake_log(seed_text, next_words=10, model=model, max_sequence_length=max_sequence_length)
    print(fake_log)
    # print("\n" + "="*50 + "\n")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1916
# 1/1 [==============================] - 0s 19ms/step
# i
# 1/1 [==============================] - 0s 19ms/step
# microsoft
# 1/1 [==============================] - 0s 18ms/step
# 1701637300081273
# 1/1 [==============================] - 0s 18ms/step
# launch
# 1/1 [==============================] - 0s 19ms/step
# time
# 1/1 [==============================] - 0s 17ms/step
# ticks
# 1/1 [==============================] - 0s 17ms/step
# at
# 1/1 [==============================] - 0s 18ms/step
# field
# 1/1 [==============================] - 0s 16ms/step
# trial
# Process Create:
# RuleName: -
# UtcTime: 2023-12-03 22:08:38.636
# ProcessGuid: {1c492278-fc66-656c-aa02-000000000500}
# ProcessId: 6132
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# FileVersion: 119.0.6045.200
# Description: Google Chrome
# Product: Google Chrome
# Company: Google LLC
# OriginalFileName: chrome.exe
# CommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe" --type=renderer --enable-chrome-cart --disable-nacl --disable-gpu-compositing --lang=en-US --device-scale-factor=1 --num-raster-threads=2 --enable-main-frame-before-activation --renderer-client-id=108 --time-ticks-at-unix-epoch=-1701637300081273 --launch-time-ticks=4018682745 --mojo-platform-channel-handle=10540 --field-trial-handle=1916,i,17040888337244139981,11734970527589297732,262144 /prefetch:1
# CurrentDirectory: C:\Program Files\Google\Chrome\Application\119.0.6045.200\
# User: WINDOWS-10-VM\user1
# LogonGuid: {1c492278-ecbc-656c-ac18-030000000000}
# LogonId: 0x318AC
# TerminalSessionId: 1
# IntegrityLevel: Low
# Hashes: SHA256=33F662AEC0E59C12809D5F4CF04E6626AC08728CDC2835EAD0650910BDF0F772
# ParentProcessGuid: {1c492278-ece7-656c-8600-000000000500}
# ParentProcessId: 7420
# ParentImage: C:\Program Files\Google\Chrome\Application\chrome.exe
# ParentCommandLine: "C:\Program Files\Google\Chrome\Application\chrome.exe"
# ParentUser: WINDOWS-10-VM\user1 1916 i microsoft 1701637300081273 launch time ticks at field trial
# 1/1 [==============================] - 0s 17ms/step
# nativeimages
# 1/1 [==============================] - 0s 18ms/step
# v4
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 17ms/step
# 30319
# 1/1 [==============================] - 0s 18ms/step
# ngen
# 1/1 [==============================] - 0s 18ms/step
# v4
# 1/1 [==============================] - 0s 17ms/step
# 0
# 1/1 [==============================] - 0s 18ms/step
# 30319
# 1/1 [==============================] - 0s 18ms/step
# ngen
# 1/1 [==============================] - 0s 19ms/step
# v4
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 22:08:43.819
# ProcessGuid: {1c492278-fc68-656c-af02-000000000500}
# ProcessId: 4036
# Image: C:\Program Files\Google\Chrome\Application\chrome.exe
# User: WINDOWS-10-VM\user1 nativeimages v4 0 30319 ngen v4 0 30319 ngen v4
# 1/1 [==============================] - 0s 20ms/step
# 1916
# 1/1 [==============================] - 0s 17ms/step
# i
# 1/1 [==============================] - 0s 17ms/step
# 17040888337244139981
# 1/1 [==============================] - 0s 18ms/step
# 11734970527589297732
# 1/1 [==============================] - 0s 19ms/step
# user1
# 1/1 [==============================] - 0s 18ms/step
# 1916
# 1/1 [==============================] - 0s 18ms/step
# i
# 1/1 [==============================] - 0s 17ms/step
# 17040888337244139981
# 1/1 [==============================] - 0s 18ms/step
# 11734970527589297732
# 1/1 [==============================] - 0s 17ms/step
# 262144
# Process terminated:
# RuleName: -
# UtcTime: 2023-12-03 21:46:22.126
# ProcessGuid: {1c492278-f729-656c-5801-000000000500}
# ProcessId: 5792
# Image: C:\Windows\System32\dllhost.exe
# User: WINDOWS-10-VM\user1 1916 i 17040888337244139981 11734970527589297732 user1 1916 i 17040888337244139981 11734970527589297732 262144
